# %% [markdown]
# SINGLE LINE COMMENTS

# %%
# we use single # and double ## for a single line comments
# Example of multi line comments
# I love Coding
## I like movies
# I am a good boy
a=20
print(a)
# Out:
# 20

# %% [markdown]
# MULTI LINE COMMENTS

# %%
"""we use triple quotes """ """ for a multi line quotes 
Example of multi line comments
I love Coding
I like movies
I am a good boy"""
a=20
print(a)
# Out:
# 20

# %% [markdown]
# # MARKDOWN is specially used for title or heading and its size reduces like h1,h2... tag in html in this we use # instead of h1,h2,...
# ## MARKDOWN
# ### MARKDOWN1
# #### MARKDOWN2
# 1.I like movies

# %% [markdown]
# # NUMBERS

# %%
# without print function output is not shown on terminal
1+3
# Out:
# 4

# %%
#with print function output is shown on terminal
print(1+3)
# Out:
# 4

# %%
a=5
a
# Out:
# 5

# %%
a=5
print(a)
# Out:
# 5

# %% [markdown]
# # \n means take it to the new line
# print("I live movies \n I am a good boy")

# %% [markdown]
# ## Variable assignment

# %%
name ="Rachit"
company="Pachauri"

# %%
print(name)
# Out:
# Rachit

# %%
name
# Out:
# 'Rachit'

# %%
name="harsh"
name
# Out:
# 'harsh'

# %%
print(name)
# Out:
# harsh

# %%
print(company)
# Out:
# Pachauri

# %%
company
# Out:
# 'Pachauri'

# %%
number=10

# %%
number =20

# %%
number
# Out:
# 20

# %%
print(number)
# Out:
# 20

# %%
# for checking in built function, type()  fuction is used
type("Rachit")
# Out:
# str

# %%
type(name)
# Out:
# str

# %%
type(number)
# Out:
# int

# %%
decimal_num=2.5

# %%
decimal_num
# Out:
# 2.5

# %%
print(decimal_num)
# Out:
# 2.5

# %%
type(decimal_num)
# Out:
# float

# %%
type("hello")
# Out:
# str

# %%
#Complex number
type(1+2j)
# Out:
# complex

# %%
"""type("hello") =str
type('hello')=str
type(2.5)=float
type(5)=int
type(1+4j)=complex"""
type(2.5)
# Out:
# float

# %%
type('hello')
# Out:
# str

# %%
##bad way to declare variable
## don't start variable name with numbers
1a
3answer

# %%
#Good way to declare variable
number1=23

# %%
##Variable are case sensitive
company="ineuron"
Company="PWSKILLS"
print(company)
print(Company)
# Out:
# ineuron
# PWSKILLS

# %%
## Reserved keywords
'''
int,float,len,complex,bool,str,return,yield
'''

# %%
##Boolean
True
# Out:
# True

# %%
False
# Out:
# False

# %%
#Lgic gates
True and False
# Out:
# False

# %%
True or False
# Out:
# True

# %%
not True
# Out:
# False

# %%
type(not False)
# Out:
# bool

# %%
##Typecasting
bool(0)
# Out:
# False

# %%
bool(1)
# Out:
# True

# %%
str(23)
# Out:
# '23'

# %%
int("23")
# Out:
# 23

# %%
int(True)
# Out:
# 1

# %%
int(1.54)
# Out:
# 1

# %% [markdown]
# ### Dynamic Typing

# %%
a=12
str1="Rachit"
a="var"

# %%
print(type(a))
# Out:
# <class 'str'>

# %%
## concatenation between different types
# for concatenation the datatype should be same

# %%
int("1")+int("1")
# Out:
# 2

# %%
"1"+"1"
# Out:
# '11'

# %%
"1"*100
# Out:
# '1111111111111111111111111111111111111111111111111111111111111111111111111111111111111111111111111111'

# %%
True
# Out:
# 100
